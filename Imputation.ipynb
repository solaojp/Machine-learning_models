# %%
import pandas as pd
import os
import numpy as np

data = pd.read_csv("diabetes.csv")
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
print(data.describe())
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
print((data.iloc[:,[1,2,3,4,5]] == 0).sum())
print(data.isnull().sum())
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
data.iloc[:,[1,2,3,4,5]] = data.iloc[:,[1,2,3,4,5]].replace(0,np.NAN)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull(),cbar = False)

# %%
import missingno as msno

# %%
msno.matrix(data)

# %%
data.iloc[:,[1]] = data.iloc[:,[1]].replace(np.NaN, 117)
data.iloc[:,[2]] = data.iloc[:,[2]].replace(np.NaN, 72)
data.iloc[:,[3]] = data.iloc[:,[3]].replace(np.NaN, 29)
data.iloc[:,[4]] = data.iloc[:,[4]].replace(np.NaN, 125)
data.iloc[:,[5]] = data.iloc[:,[5]].replace(np.NaN, 32.30)
# count the number of NaN values in each column
print(data.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(data.head(10))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
# 5            5    116.0           74.0           29.0    125.0  25.6
# 6            3     78.0           50.0           32.0     88.0  31.0
# 7           10    115.0           72.0           29.0    125.0  35.3
# 8            2    197.0           70.0           45.0    543.0  30.5
# 9            8    125.0           96.0           29.0    125.0  32.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...
