# %%
import os
import pandas as pd
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter


data = pd.read_csv("nyc-rolling-sales.csv")
data.head(5)
# Out:
#    Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0           4        1  ALPHABET CITY
# 1           5        1  ALPHABET CITY
# 2           6        1  ALPHABET CITY
# 3           7        1  ALPHABET CITY
# 4           8        1  ALPHABET CITY
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  07 RENTALS - WALKUP APARTMENTS                                2A    392
# 1  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 2  07 RENTALS - WALKUP APARTMENTS                                 2    399
# 3  07 RENTALS - WALKUP APARTMENTS                                2B    402
# 4  07 RENTALS - WALKUP APARTMENTS                                2A    404
#
#    LOT EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  ... Resi  \
# 0    6                                  C2            153 AVENUE B  ...    5
# 1   26                                  C7   234 EAST 4TH   STREET  ...   28
# ...

# %%
print(data.describe())
# Out:
#          Unnamed: 0       BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  84548.000000  84548.000000  84548.000000  84548.000000  84548.000000
# mean   10344.359878      2.998758   4237.218976    376.224015  10731.991614
# std     7151.779436      1.289790   3568.263407    658.136814   1290.879147
# min        4.000000      1.000000      1.000000      1.000000      0.000000
# 25%     4231.000000      2.000000   1322.750000     22.000000  10305.000000
# 50%     8942.000000      3.000000   3311.000000     50.000000  11209.000000
# 75%    15987.250000      4.000000   6281.000000   1001.000000  11357.000000
# max    26739.000000      5.000000  16322.000000   9106.000000  11694.000000
#
#                Resi        Commer         Total    YEAR BUILT  \
# count  84548.000000  84548.000000  84548.000000  84548.000000
# mean       2.025264      0.193559      2.249184   1789.322976
# std       16.721037      8.713183     18.972584    537.344993
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                        0
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# Resi                              0
# Commer                            0
# Total                             0
# LS                                0
# GS                                0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# Sale                              0
# SALE DATE                         0
# dtype: int64

# %% [markdown]
# No null data present. So imputation is not needed.

# %%
# Working with Melbourne dataset

# %%
data1 = pd.read_csv("realestate.csv")
data1.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0       3.0       2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    BuildingArea  YearBuilt CouncilArea Lattitude Longtitude
# 0           NaN        NaN       Yarra  -37.8014   144.9958
# ...

# %%
data1.isnull().sum()
# Out:
# Suburb             4
# Address           14
# Rooms             24
# Type              24
# Price           3177
# Method            24
# SellerG           24
# Date              24
# Distance          24
# Postcode          24
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# CouncilArea     3063
# Lattitude       2940
# Longtitude      2939
# dtype: int64

# %%
Counter(data1['Suburb'])
# Out:
# Counter({'Abbotsford': 78,
#          'Airport West': 75,
#          'Albert Park': 78,
#          'Alphington': 42,
#          'Altona': 62,
#          'Altona North': 94,
#          'Armadale': 139,
#          'Ascot Vale': 130,
#          'Ashburton': 90,
#          'Ashwood': 82,
#          'Avondale Heights': 88,
#          'Balaclava': 26,
#          'Balwyn': 180,
#          'Balwyn North': 224,
#          '    RE': 20,
#          'Bentleigh': 170,
#          'Bentleigh East': 314,
#          'Box Hill': 71,
#          'Braybrook': 55,
#          'Brighton': 248,
#          'Brighton East': 226,
#          'Brunswick': 228,
#          'Brunswick West': 126,
#          'Bulleen': 91,
#          'Burwood': 135,
#          'Camberwell': 226,
#          'Canterbury': 73,
#          'Carlton North': 52,
#          'Carnegie': 161,
#          'Caulfield': 14,
#          'Caulfield North': 44,
#          'Caulfield South': 64,
#          'Chadstone': 64,
# ...

# %%
#Fill empty data with 'Reservoir'
Suburb_null = data1[data1['Suburb'].isnull()].index.tolist()
data1['Suburb'].iloc[Suburb_null] = "Reservoir"
Counter(data1['Suburb'])

#Reservoir number changed from 444 to 448
# Out:
# Counter({'Abbotsford': 78,
#          'Airport West': 75,
#          'Albert Park': 78,
#          'Alphington': 42,
#          'Altona': 62,
#          'Altona North': 94,
#          'Armadale': 139,
#          'Ascot Vale': 130,
#          'Ashburton': 90,
#          'Ashwood': 82,
#          'Avondale Heights': 88,
#          'Balaclava': 26,
#          'Balwyn': 180,
#          'Balwyn North': 224,
#          '    RE': 20,
#          'Bentleigh': 170,
#          'Bentleigh East': 314,
#          'Box Hill': 71,
#          'Braybrook': 55,
#          'Brighton': 248,
#          'Brighton East': 226,
#          'Brunswick': 228,
#          'Brunswick West': 126,
#          'Bulleen': 91,
#          'Burwood': 135,
#          'Camberwell': 226,
#          'Canterbury': 73,
#          'Carlton North': 52,
#          'Carnegie': 161,
#          'Caulfield': 14,
#          'Caulfield North': 44,
#          'Caulfield South': 64,
#          'Chadstone': 64,
# ...

# %%
Counter(data1['Address'])
# Out:
# Counter({'68 Studley St': 1,
#          '85 Turner St': 1,
#          '25 Bloomburg St': 1,
#          '18/659 Victoria St': 1,
#          '5 Charles St': 5,
#          '40 Federation La': 1,
#          '55a Park St': 1,
#          '16 Maugie St': 1,
#          '53 Turner St': 1,
#          '99 Turner St': 1,
#          '129 Charles St': 1,
#          '124 Yarra St': 1,
#          '121/56 Nicholson St': 1,
#          '17 Raphael St': 1,
#          '98 Charles St': 1,
#          '217 Langridge St': 1,
#          '18a Mollison St': 1,
#          '6/241 Nicholson St': 1,
#          '10 Valiant St': 1,
#          '403/609 Victoria St': 1,
#          '2 Rich St': 1,
#          '25/84 Trenerry Cr': 1,
#          '106/119 Turner St': 1,
#          '411/8 Grosvenor St': 1,
#          '40 Nicholson St': 1,
#          '123/56 Nicholson St': 1,
#          '22 Park St': 2,
#          '13/84 Trenerry Cr': 1,
#          '45 William St': 1,
#          '7/20 Abbotsford St': 1,
# ...

# %%
#Fill empty data with 'Reservoir'
Address_null = data1[data1['Address'].isnull()].index.tolist()
data1['Address'].iloc[Suburb_null] = "51 Elliott Av"
Counter(data1['Address'])
# Out:
# Counter({'68 Studley St': 1,
#          '85 Turner St': 1,
#          '25 Bloomburg St': 1,
#          '18/659 Victoria St': 1,
#          '5 Charles St': 5,
#          '40 Federation La': 1,
#          '55a Park St': 1,
#          '16 Maugie St': 1,
#          '53 Turner St': 1,
#          '99 Turner St': 1,
#          '129 Charles St': 1,
#          '124 Yarra St': 1,
#          '121/56 Nicholson St': 1,
#          '17 Raphael St': 1,
#          '98 Charles St': 1,
#          '217 Langridge St': 1,
#          '18a Mollison St': 1,
#          '6/241 Nicholson St': 1,
#          '10 Valiant St': 1,
#          '403/609 Victoria St': 1,
#          '2 Rich St': 1,
#          '25/84 Trenerry Cr': 1,
#          '106/119 Turner St': 1,
#          '411/8 Grosvenor St': 1,
#          '40 Nicholson St': 1,
#          '123/56 Nicholson St': 1,
#          '22 Park St': 2,
#          '13/84 Trenerry Cr': 1,
#          '45 William St': 1,
#          '7/20 Abbotsford St': 1,
# ...

# %%
Counter(data1['Rooms'])
# Out:
# Counter({2.0: 4197,
#          3.0: 5800,
#          4.0: 2707,
#          1.0: 801,
#          5.0: 629,
#          6.0: 60,
#          7.0: 10,
#          8.0: 11,
#          4197.0: 24,
#          10.0: 3,
#          9.0: 2,
#          12.0: 2})

# %%
Rooms_null = data1[data1['Rooms'].isnull()].index.tolist()
data1['Rooms'].iloc[Rooms_null] = 4197
Counter(data1['Rooms'])
# Out:
# Counter({2.0: 4197,
#          3.0: 5800,
#          4.0: 2707,
#          1.0: 801,
#          5.0: 629,
#          6.0: 60,
#          7.0: 10,
#          8.0: 11,
#          4197.0: 24,
#          10.0: 3,
#          9.0: 2,
#          12.0: 2})

# %%
Counter(data1['Type'])
# Out:
# Counter({'h': 9104, 'u': 3568, 't': 1574})

# %%
Type_null = data1[data1['Type'].isnull()].index.tolist()
data1['Type'].iloc[Type_null] = 'h'
Counter(data1['Rooms'])
# Out:
# Counter({'h': 9104, 'u': 3568, 't': 1574})

# %%
Counter(data1['Method'])
# Out:
# Counter({'SS': 12,
#          'S': 8406,
#          'VB': 1098,
#          'SP': 2013,
#          'PI': 1883,
#          'SN': 587,
#          'W': 51,
#          'PN': 121,
#          'SA': 51,
#          nan: 24})

# %%
Method_null = data1[data1['Method'].isnull()].index.tolist()
data1['Method'].iloc[Method_null] = "S"
Counter(data1['Method'])
# Out:
# Counter({'SS': 12,
#          'S': 8430,
#          'VB': 1098,
#          'SP': 2013,
#          'PI': 1883,
#          'SN': 587,
#          'W': 51,
#          'PN': 121,
#          'SA': 51})

# %%
Counter(data1['SellerG'])
# Out:
# Counter({'Jellis': 1553,
#          'Biggin': 449,
#          'Rounds': 2,
#          'Nelson': 1657,
#          'Collins': 62,
#          'Dingle': 34,
#          'Purplebricks': 29,
#          'Greg': 257,
#          'Philip': 38,
#          'LITTLE': 43,
#          'Kay': 206,
#          'Beller': 23,
#          'Marshall': 1038,
#          'hockingstuart': 1284,
#          'Brad': 361,
#          'Maddison': 5,
#          'Barry': 990,
#          'Airport': 1,
#          'Considine': 31,
#          'Rendina': 79,
#          'Ray': 534,
#          'Propertyau': 1,
#          'McDonald': 34,
#          'Frank': 47,
#          'Prof.': 4,
#          'Harcourts': 68,
#          'Thomson': 47,
#          'Buxton': 758,
#          'RT': 297,
#          "Sotheby's": 11,
#          'Cayzer': 56,
#          'Chisholm': 88,
#          'McGrath': 181,
#          'Brace': 16,
#          'Miles': 260,
#          'Holland': 9,
#          'Love': 97,
#          'Thomas': 3,
# ...

# %%
seller_null = data1[data1['SellerG'].isnull()].index.tolist()
data1['SellerG'].iloc[Method_null] = "Nelson"

# %%
Counter(data1['Distance'])
# Out:
# Counter({2.5: 106,
#          13.5: 180,
#          3.3: 320,
#          6.4: 185,
#          13.8: 234,
#          11.1: 94,
#          6.3: 139,
#          5.9: 256,
#          11.0: 90,
#          12.2: 82,
#          10.5: 175,
#          6.6: 87,
#          9.7: 274,
#          9.2: 665,
#          nan: 1,
#          nan: 1,
#          13.0: 427,
#          13.9: 499,
#          13.1: 71,
#          10.8: 55,
#          11.2: 1136,
#          nan: 1,
#          nan: 1,
#          10.7: 226,
#          5.2: 228,
#          11.8: 240,
#          11.7: 135,
#          nan: 1,
#          nan: 1,
#          7.8: 491,
#          9.0: 102,
#          3.2: 52,
#          11.4: 260,
#          8.9: 37,
#          8.1: 44,
#          9.3: 76,
#          13.6: 91,
#          3.4: 71,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          nan: 1,
#          1.6: 145,
#          10.3: 34,
#          8.5: 79,
#          7.7: 187,
#          8.0: 339,
#          9.4: 94,
# ...

# %%
Distance_null = data1[data1['Distance'].isnull()].index.tolist()
data1['Distance'].iloc[Distance_null] = 13.9

# %%
data1.isnull().sum()
# Out:
# Suburb             0
# Address           10
# Rooms              0
# Type               0
# Price           3177
# Method             0
# SellerG            0
# Date              24
# Distance           0
# Postcode          24
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# CouncilArea     3063
# Lattitude       2940
# Longtitude      2939
# dtype: int64

# %%
Counter(data1["Postcode"])


data1['Postcode'].iloc[postcode_null] = 3073.0

# %%
data1.groupby(data1['Type'])['Price'].mean()
# Out:
# Type
# h    1.301827e+06
# t    9.152002e+05
# u    6.082769e+05
# Name: Price, dtype: float64

# %%
pd.crosstab( data1['Price'].isnull(), data1['Type'])
# Out:
# Type      h     t     u
# Price
# False  6923  1259  2887
# True   2181   315   681

# %%
price_null = data1[data1['Price'].isnull()].index.tolist()
data1['Price'].iloc[price_null] = 8200000000
# Out:
# /Users/jagruti/Desktop/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data1.isnull().sum()
# Out:
# Suburb             0
# Address           10
# Rooms              0
# Type               0
# Price              0
# Method             0
# SellerG            0
# Date              24
# Distance           0
# Postcode           0
# Bedroom2        3044
# Bathroom        3044
# Car             3044
# Landsize        3061
# BuildingArea    8078
# YearBuilt       7147
# CouncilArea     3063
# Lattitude       2940
# Longtitude      2939
# dtype: int64
